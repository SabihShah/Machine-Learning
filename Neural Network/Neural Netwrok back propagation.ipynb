# %%
import numpy as np

# Define sigmoid activation function
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# Define derivative of sigmoid function
def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# %%
# Initialize inputs and outputs
x1 = 0.92
x2 = 0.42

y1 = 0
y2 = 1


# Initialize weights and biases
def initialize():
    hidden_w = np.random.rand(2,2)
    output_w = np.random.rand(2,2)
    hidden_biases = np.random.rand(2,1)
    output_biases = np.random.rand(2,1)
    print('Hidden Layer Weights:', hidden_w)
    print('Output Layer Weights:', output_w)
    print('Hidden Layer Biases:', hidden_biases)
    print('Output Layer Biases:', output_biases)
    return hidden_w, output_w, hidden_biases, output_biases

# Forward Propagation
def forward(x1, x2, hidden_w, output_w, biases_hidden, biases_output):
    z_layer_2 = np.dot(hidden_w, np.array([[x1],[x2]])) + biases_hidden
    hidden_activations = sigmoid(z_layer_2)
    z_layer_3 = np.dot(output_w, hidden_activations) + biases_output
    output_activations = sigmoid(z_layer_3)

    return z_layer_2, hidden_activations, z_layer_3, output_activations


# Define Mean Squared Error loss function
def mse_loss(y1,y2,output_activations):
    e1 = (1/2)*((y1 - output_activations[0])**2)
    e2 = (1/2)*((y2 - output_activations[1])**2)
    mse = e1 + e2
    print('Loss:', mse)
    return mse

# %%
# Backpropagation

def back_prop(x1,x2,y1,y2,weights_output,output_activations, z_layer_2, z_layer_3, hidden_activations):

    # output weights
    dE_dy_output = output_activations - np.array([[y1],[y2]])
    dy_dz_output = sigmoid_derivative(z_layer_3)
    dz_dw_output = hidden_activations.T

    dE_dw_output = np.dot(dE_dy_output*dy_dz_output, dz_dw_output)

    # Hidden Weights
    dz_dy_hidden = weights_output
    dy_dz_hidden = sigmoid_derivative(z_layer_2)
    dz_dx_hidden = np.array([[x1],[x2]])
    dE_dy_hidden = np.dot(dz_dy_hidden, dE_dy_output * dy_dz_output)
    dE_dz_hidden = dE_dy_hidden * dy_dz_hidden
    dE_dw_hidden = np.dot(dz_dx_hidden, dE_dz_hidden.T)

    return dE_dw_output, dE_dw_hidden

# %%
# Update weights
def update(lr, hidden_w, dE_dw_hidden, output_w, dE_dw_output):
    hidden_w = hidden_w - (lr*dE_dw_hidden)
    output_w = output_w - (lr*dE_dw_output)

    print('Updated Hidden Layer Weights:', hidden_w)
    print('Updated Output Layer Weights:', output_w)

    return hidden_w, output_w

# %%
x1 = 0.92
x2 = 0.42

y1 = 0.3
y2 = 0.7

lr = 5

hidden_w, output_w, hidden_biases, output_biases = initialize()

# hidden_layer_biases = np.array([[0.4], [0.4]])
# output_layer_biases = np.array([[0.5], [0.5]])
# print('Hidden Layer Biases:', hidden_layer_biases)
# print('Output Layer Biases:', output_layer_biases)

# hidden_layer_weights = np.array([[0.3, 0.7], [0.2, 0.8]])
# output_layer_weights = np.array([[0.2, 0.5], [0.8, 0.5]])
# print('Original Hidden layer weights:', hidden_layer_weights)
# print('Original Output layer weights:', output_layer_weights)

n = 1000
loss = []

for i in range(1,n+1):
    print('================================================')
    print(f'Iteration {i}:')
    z_layer_2, hidden_activations, z_layer_3, output_activations = forward(x1, x2, hidden_w, output_w,
                                                                        hidden_biases, output_biases)
    mse = mse_loss(y1,y2, output_activations)

    dE_dw_output, dE_dw_hidden = back_prop(x1, x2, y1, y2, output_w, 
                                                 output_activations, z_layer_2, z_layer_3, hidden_activations)
    
    hidden_w, output_w = update(lr, hidden_w, dE_dw_hidden, output_w, dE_dw_output)

    loss.append(mse)


mse = mse_loss(y1,y2,output_activations)
# Out:
# Hidden Layer Weights: [[0.56815589 0.78921846]
#  [0.12995587 0.93931591]]
# Output Layer Weights: [[0.67983113 0.77730998]
#  [0.31241419 0.44201087]]
# Hidden Layer Biases: [[0.02616787]
#  [0.94895959]]
# Output Layer Biases: [[0.198776  ]
#  [0.87553342]]
# ================================================
# Iteration 1:
# Loss: [0.12501621]
# Updated Hidden Layer Weights: [[0.50271072 0.76604731]
#  [0.10007873 0.92873777]]
# Updated Output Layer Weights: [[0.39152887 0.44614224]
#  [0.25233528 0.37299928]]
# ================================================
# Iteration 2:
# Loss: [0.08298609]
# Updated Hidden Layer Weights: [[0.46381355 0.74678357]
#  [0.08232133 0.91994345]]
# Updated Output Layer Weights: [[0.10148007 0.10795644]
#  [0.19899868 0.31081084]]
# ================================================
# Iteration 3:
# Loss: [0.04455263]
# Updated Hidden Layer Weights: [[0.45529695 0.73365026]
#  [0.07843331 0.91394782]]
# Updated Output Layer Weights: [[-0.13656812 -0.17233645]
#  [ 0.15246125  0.25601476]]
# ================================================
# Iteration 4:
# Loss: [0.02057534]
# Updated Hidden Layer Weights: [[0.46389058 0.72613014]
#  [0.08235649 0.91051472]]
# Updated Output Layer Weights: [[-0.29959813 -0.36488592]
#  [ 0.11234339  0.20863285]]
# ================================================
# Iteration 5:
# Loss: [0.00938705]
# Updated Hidden Layer Weights: [[0.4767615  0.7220984 ]
#  [0.08823235 0.90867414]]
# Updated Output Layer Weights: [[-0.4044585  -0.48859809]
#  [ 0.07828674  0.16845349]]
# ================================================
# Iteration 6:
# Loss: [0.00452054]
# Updated Hidden Layer Weights: [[0.48885823 0.71994965]
#  [0.09375477 0.90769319]]
# Updated Output Layer Weights: [[-0.472787   -0.56902409]
#  [ 0.04992854  0.1350745 ]]
# ================================================
# Iteration 7:
# Loss: [0.00229488]
# Updated Hidden Layer Weights: [[0.49894911 0.71880708]
#  [0.09836147 0.90717158]]
# Updated Output Layer Weights: [[-0.51863646 -0.6228663 ]
#  [ 0.02677006  0.1078789 ]]
# ================================================
# Iteration 8:
# Loss: [0.00120812]
# Updated Hidden Layer Weights: [[0.50699272 0.71820906]
#  [0.10203356 0.90689857]]
# Updated Output Layer Weights: [[-0.55021035 -0.65987103]
#  [ 0.00818448  0.08609651]]
# ================================================
# Iteration 9:
# Loss: [0.00065048]
# Updated Hidden Layer Weights: [[0.51326369 0.71790676]
#  [0.10489639 0.90676056]]
# Updated Output Layer Weights: [[-0.57238497 -0.68581833]
#  [-0.00651304  0.06889843]]
# ================================================
# Iteration 10:
# Loss: [0.00035493]
# Updated Hidden Layer Weights: [[0.5180895  0.71776343]
#  [0.10709948 0.90669513]]
# Updated Output Layer Weights: [[-0.58818278 -0.70428075]
#  [-0.0179967   0.05547783]]
# ================================================
# Iteration 11:
# Loss: [0.00019515]
# Updated Hidden Layer Weights: [[0.52177147 0.71770354]
#  [0.10878038 0.90666779]]
# Updated Output Layer Weights: [[-0.59955423 -0.71755734]
#  [-0.02688333  0.04510236]]
# ================================================
# Iteration 12:
# Loss: [0.00010776]
# Updated Hidden Layer Weights: [[0.52456373 0.71768568]
#  [0.11005511 0.90665964]]
# Updated Output Layer Weights: [[-0.60780054 -0.72717807]
#  [-0.03370843  0.03713971]]
# ================================================
# Iteration 13:
# Loss: [5.9648201e-05]
# Updated Hidden Layer Weights: [[0.52667192 0.71768757]
#  [0.11101754 0.9066605 ]]
# Updated Output Layer Weights: [[-0.61381269 -0.73418834]
#  [-0.03891954  0.03106347]]
# ================================================
# Iteration 14:
# Loss: [3.30578723e-05]
# Updated Hidden Layer Weights: [[0.52825837 0.71769754]
#  [0.11174179 0.90666505]]
# Updated Output Layer Weights: [[-0.61821299 -0.73931696]
#  [-0.04288042  0.026447  ]]
# ================================================
# Iteration 15:
# Loss: [1.83328734e-05]
# Updated Hidden Layer Weights: [[0.52944925 0.71770975]
#  [0.11228545 0.90667063]]
# Updated Output Layer Weights: [[-0.6214426  -0.74307992]
#  [-0.04588065  0.0229513 ]]
# ================================================
# Iteration 16:
# Loss: [1.01699068e-05]
# Updated Hidden Layer Weights: [[0.53034153 0.71772151]
#  [0.1126928  0.90667599]]
# Updated Output Layer Weights: [[-0.62381777 -0.74584666]
#  [-0.04814727  0.020311  ]]
# ================================================
# Iteration 17:
# Loss: [5.64230699e-06]
# Updated Hidden Layer Weights: [[0.53100914 0.71773173]
#  [0.11299757 0.90668066]]
# Updated Output Layer Weights: [[-0.62556709 -0.74788402]
#  [-0.04985627  0.01832061]]
# ================================================
# Iteration 18:
# Loss: [3.13048523e-06]
# Updated Hidden Layer Weights: [[0.53150811 0.71774013]
#  [0.11322537 0.90668449]]
# Updated Output Layer Weights: [[-0.62685681 -0.7493859 ]
#  [-0.0511429   0.01682233]]
# ================================================
# Iteration 19:
# Loss: [1.73686309e-06]
# Updated Hidden Layer Weights: [[0.53188075 0.7177468 ]
#  [0.11339548 0.90668754]]
# Updated Output Layer Weights: [[-0.62780839 -0.75049389]
#  [-0.05211046  0.01569573]]
# ================================================
# Iteration 20:
# Loss: [9.63638334e-07]
# Updated Hidden Layer Weights: [[0.53215887 0.717752  ]
#  [0.11352245 0.90668991]]
# Updated Output Layer Weights: [[-0.62851084 -0.75131174]
#  [-0.05283745  0.0148493 ]]
# ================================================
# Iteration 21:
# Loss: [5.34636704e-07]
# Updated Hidden Layer Weights: [[0.53236636 0.71775598]
#  [0.11361717 0.90669173]]
# Updated Output Layer Weights: [[-0.62902956 -0.75191565]
#  [-0.05338335  0.01421375]]
# ================================================
# Iteration 22:
# Loss: [2.96622602e-07]
# Updated Hidden Layer Weights: [[0.5325211  0.71775899]
#  [0.11368781 0.9066931 ]]
# Updated Output Layer Weights: [[-0.6294127  -0.75236169]
#  [-0.05379307  0.01373677]]
# ================================================
# Iteration 23:
# Loss: [1.64572069e-07]
# Updated Hidden Layer Weights: [[0.53263646 0.71776126]
#  [0.11374048 0.90669414]]
# Updated Output Layer Weights: [[-0.62969573 -0.75269117]
#  [-0.05410046  0.01337892]]
# ================================================
# Iteration 24:
# Loss: [9.13104023e-08]
# Updated Hidden Layer Weights: [[0.53272246 0.71776295]
#  [0.11377974 0.90669491]]
# Updated Output Layer Weights: [[-0.62990482 -0.75293458]
#  [-0.05433104  0.01311051]]
# ================================================
# Iteration 25:
# Loss: [5.06643113e-08]
# Updated Hidden Layer Weights: [[0.53278655 0.71776422]
#  [0.113809   0.90669549]]
# Updated Output Layer Weights: [[-0.63005929 -0.7531144 ]
#  [-0.05450395  0.01290922]]
# ================================================
# Iteration 26:
# Loss: [2.81129744e-08]
# Updated Hidden Layer Weights: [[0.53283432 0.71776515]
#  [0.11383081 0.90669592]]
# Updated Output Layer Weights: [[-0.63017341 -0.75324725]
#  [-0.0546336   0.0127583 ]]
# ================================================
# Iteration 27:
# Loss: [1.56005049e-08]
# Updated Hidden Layer Weights: [[0.53286991 0.71776585]
#  [0.11384706 0.90669623]]
# Updated Output Layer Weights: [[-0.63025772 -0.75334538]
#  [-0.0547308   0.01264515]]
# ================================================
# Iteration 28:
# Loss: [8.65768119e-09]
# Updated Hidden Layer Weights: [[0.53289644 0.71776636]
#  [0.11385917 0.90669647]]
# Updated Output Layer Weights: [[-0.63031999 -0.75341787]
#  [-0.05480367  0.01256033]]
# ================================================
# Iteration 29:
# Loss: [4.80506171e-09]
# Updated Hidden Layer Weights: [[0.5329162  0.71776674]
#  [0.11386819 0.90669664]]
# Updated Output Layer Weights: [[-0.63036599 -0.75347141]
#  [-0.05485829  0.01249674]]
# ================================================
# Iteration 30:
# Loss: [2.6670657e-09]
# Updated Hidden Layer Weights: [[0.53293092 0.71776702]
#  [0.11387491 0.90669677]]
# Updated Output Layer Weights: [[-0.63039996 -0.75351096]
#  [-0.05489924  0.01244908]]
# ================================================
# Iteration 31:
# Loss: [1.48049982e-09]
# Updated Hidden Layer Weights: [[0.53294189 0.71776722]
#  [0.11387992 0.90669686]]
# Updated Output Layer Weights: [[-0.63042504 -0.75354016]
#  [-0.05492993  0.01241335]]
# ================================================
# Iteration 32:
# Loss: [8.21911618e-10]
# Updated Hidden Layer Weights: [[0.53295007 0.71776737]
#  [0.11388365 0.90669693]]
# Updated Output Layer Weights: [[-0.63044356 -0.75356172]
#  [-0.05495294  0.01238657]]
# ================================================
# Iteration 33:
# Loss: [4.56337282e-10]
# Updated Hidden Layer Weights: [[0.53295615 0.71776748]
#  [0.11388643 0.90669698]]
# Updated Output Layer Weights: [[-0.63045724 -0.75357764]
#  [-0.05497018  0.0123665 ]]
# ================================================
# Iteration 34:
# Loss: [2.53391818e-10]
# Updated Hidden Layer Weights: [[0.53296069 0.71776756]
#  [0.1138885  0.90669702]]
# Updated Output Layer Weights: [[-0.63046733 -0.75358939]
#  [-0.05498311  0.01235145]]
# ================================================
# Iteration 35:
# Loss: [1.40717006e-10]
# Updated Hidden Layer Weights: [[0.53296407 0.71776762]
#  [0.11389004 0.90669704]]
# Updated Output Layer Weights: [[-0.63047478 -0.75359806]
#  [-0.05499279  0.01234018]]
# ================================================
# Iteration 36:
# Loss: [7.81536673e-11]
# Updated Hidden Layer Weights: [[0.53296659 0.71776767]
#  [0.11389119 0.90669706]]
# Updated Output Layer Weights: [[-0.63048028 -0.75360446]
#  [-0.05500006  0.01233172]]
# ================================================
# Iteration 37:
# Loss: [4.34112421e-11]
# Updated Hidden Layer Weights: [[0.53296846 0.7177677 ]
#  [0.11389205 0.90669708]]
# Updated Output Layer Weights: [[-0.63048434 -0.75360918]
#  [-0.0550055   0.01232539]]
# ================================================
# Iteration 38:
# Loss: [2.4116059e-11]
# Updated Hidden Layer Weights: [[0.53296986 0.71776772]
#  [0.11389269 0.90669709]]
# Updated Output Layer Weights: [[-0.63048733 -0.75361266]
#  [-0.05500958  0.01232064]]
# ================================================
# Iteration 39:
# Loss: [1.33987063e-11]
# Updated Hidden Layer Weights: [[0.5329709  0.71776774]
#  [0.11389316 0.9066971 ]]
# Updated Output Layer Weights: [[-0.63048954 -0.75361523]
#  [-0.05501263  0.01231708]]
# ================================================
# Iteration 40:
# Loss: [7.44513985e-12]
# Updated Hidden Layer Weights: [[0.53297168 0.71776775]
#  [0.11389352 0.9066971 ]]
# Updated Output Layer Weights: [[-0.63049117 -0.75361713]
#  [-0.05501493  0.01231441]]
# ================================================
# Iteration 41:
# Loss: [4.13749352e-12]
# Updated Hidden Layer Weights: [[0.53297226 0.71776776]
#  [0.11389378 0.90669711]]
# Updated Output Layer Weights: [[-0.63049237 -0.75361853]
#  [-0.05501664  0.01231241]]
# ================================================
# Iteration 42:
# Loss: [2.29962612e-12]
# Updated Hidden Layer Weights: [[0.53297269 0.71776777]
#  [0.11389398 0.90669711]]
# Updated Output Layer Weights: [[-0.63049325 -0.75361956]
#  [-0.05501793  0.01231092]]
# ================================================
# Iteration 43:
# Loss: [1.27830212e-12]
# Updated Hidden Layer Weights: [[0.53297301 0.71776777]
#  [0.11389412 0.90669711]]
# Updated Output Layer Weights: [[-0.63049391 -0.75362032]
#  [-0.0550189   0.01230979]]
# ================================================
# Iteration 44:
# Loss: [7.1066847e-13]
# Updated Hidden Layer Weights: [[0.53297325 0.71776778]
#  [0.11389423 0.90669711]]
# Updated Output Layer Weights: [[-0.63049439 -0.75362088]
#  [-0.05501962  0.01230895]]
# ================================================
# Iteration 45:
# Loss: [3.95147028e-13]
# Updated Hidden Layer Weights: [[0.53297342 0.71776778]
#  [0.11389431 0.90669712]]
# Updated Output Layer Weights: [[-0.63049474 -0.75362129]
#  [-0.05502016  0.01230832]]
# ================================================
# Iteration 46:
# Loss: [2.19740125e-13]
# Updated Hidden Layer Weights: [[0.53297356 0.71776778]
#  [0.11389437 0.90669712]]
# Updated Output Layer Weights: [[-0.630495   -0.75362159]
#  [-0.05502057  0.01230785]]
# ================================================
# Iteration 47:
# Loss: [1.22213675e-13]
# Updated Hidden Layer Weights: [[0.53297366 0.71776778]
#  [0.11389442 0.90669712]]
# Updated Output Layer Weights: [[-0.63049519 -0.75362182]
#  [-0.05502087  0.01230749]]
# ================================================
# Iteration 48:
# Loss: [6.79815137e-14]
# Updated Hidden Layer Weights: [[0.53297373 0.71776778]
#  [0.11389445 0.90669712]]
# Updated Output Layer Weights: [[-0.63049534 -0.75362198]
#  [-0.0550211   0.01230723]]
# ================================================
# Iteration 49:
# Loss: [3.78201473e-14]
# Updated Hidden Layer Weights: [[0.53297378 0.71776779]
#  [0.11389448 0.90669712]]
# Updated Output Layer Weights: [[-0.63049544 -0.7536221 ]
#  [-0.05502127  0.01230703]]
# ================================================
# Iteration 50:
# Loss: [2.10434873e-14]
# Updated Hidden Layer Weights: [[0.53297383 0.71776779]
#  [0.1138945  0.90669712]]
# Updated Output Layer Weights: [[-0.63049552 -0.75362219]
#  [-0.0550214   0.01230688]]
# ================================================
# Iteration 51:
# Loss: [1.17104895e-14]
# Updated Hidden Layer Weights: [[0.53297386 0.71776779]
#  [0.11389451 0.90669712]]
# Updated Output Layer Weights: [[-0.63049557 -0.75362226]
#  [-0.0550215   0.01230677]]
# ================================================
# Iteration 52:
# Loss: [6.51772357e-15]
# Updated Hidden Layer Weights: [[0.53297388 0.71776779]
#  [0.11389452 0.90669712]]
# Updated Output Layer Weights: [[-0.63049562 -0.75362231]
#  [-0.05502157  0.01230668]]
# ================================================
# Iteration 53:
# Loss: [3.62811513e-15]
# Updated Hidden Layer Weights: [[0.5329739  0.71776779]
#  [0.11389453 0.90669712]]
# Updated Output Layer Weights: [[-0.63049565 -0.75362234]
#  [-0.05502162  0.01230662]]
# ================================================
# Iteration 54:
# Loss: [2.01990565e-15]
# Updated Hidden Layer Weights: [[0.53297391 0.71776779]
#  [0.11389453 0.90669712]]
# Updated Output Layer Weights: [[-0.63049567 -0.75362237]
#  [-0.05502166  0.01230657]]
# ================================================
# Iteration 55:
# Loss: [1.12472578e-15]
# Updated Hidden Layer Weights: [[0.53297392 0.71776779]
#  [0.11389454 0.90669712]]
# Updated Output Layer Weights: [[-0.63049568 -0.75362239]
#  [-0.05502169  0.01230654]]
# ================================================
# Iteration 56:
# Loss: [6.26366285e-16]
# Updated Hidden Layer Weights: [[0.53297392 0.71776779]
#  [0.11389454 0.90669712]]
# Updated Output Layer Weights: [[-0.6304957  -0.7536224 ]
#  [-0.05502172  0.01230651]]
# ================================================
# Iteration 57:
# Loss: [3.48880623e-16]
# Updated Hidden Layer Weights: [[0.53297393 0.71776779]
#  [0.11389454 0.90669712]]
# Updated Output Layer Weights: [[-0.63049571 -0.75362241]
#  [-0.05502173  0.01230649]]
# ================================================
# Iteration 58:
# Loss: [1.94353627e-16]
# Updated Hidden Layer Weights: [[0.53297393 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049571 -0.75362242]
#  [-0.05502174  0.01230648]]
# ================================================
# Iteration 59:
# Loss: [1.08286999e-16]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049572 -0.75362242]
#  [-0.05502175  0.01230646]]
# ================================================
# Iteration 60:
# Loss: [6.03432034e-17]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049572 -0.75362243]
#  [-0.05502176  0.01230646]]
# ================================================
# Iteration 61:
# Loss: [3.36317363e-17]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049572 -0.75362243]
#  [-0.05502177  0.01230645]]
# ================================================
# Iteration 62:
# Loss: [1.87473357e-17]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362243]
#  [-0.05502177  0.01230645]]
# ================================================
# Iteration 63:
# Loss: [1.04520045e-17]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502177  0.01230644]]
# ================================================
# Iteration 64:
# Loss: [5.82813751e-18]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230644]]
# ================================================
# Iteration 65:
# Loss: [3.25035343e-18]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230644]]
# ================================================
# Iteration 66:
# Loss: [1.81301859e-18]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230644]]
# ================================================
# Iteration 67:
# Loss: [1.01145187e-18]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 68:
# Loss: [5.6436443e-19]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 69:
# Loss: [3.14952957e-19]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 70:
# Loss: [1.75793993e-19]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 71:
# Loss: [9.81373373e-20]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 72:
# Loss: [5.47944997e-20]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 73:
# Loss: [3.05993563e-20]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 74:
# Loss: [1.70906921e-20]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 75:
# Loss: [9.54729838e-21]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 76:
# Loss: [5.33425577e-21]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 77:
# Loss: [2.98083459e-21]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 78:
# Loss: [1.66600962e-21]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 79:
# Loss: [9.31298652e-22]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 80:
# Loss: [5.20681555e-22]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 81:
# Loss: [2.91154815e-22]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 82:
# Loss: [1.62837848e-22]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 83:
# Loss: [9.10866574e-23]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 84:
# Loss: [5.09585635e-23]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 85:
# Loss: [2.85144995e-23]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 86:
# Loss: [1.59576608e-23]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 87:
# Loss: [8.9324154e-24]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 88:
# Loss: [5.00046358e-24]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 89:
# Loss: [2.80012388e-24]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 90:
# Loss: [1.56819386e-24]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 91:
# Loss: [8.78204629e-25]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 92:
# Loss: [4.91946968e-25]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 93:
# Loss: [2.7563555e-25]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 94:
# Loss: [1.54472889e-25]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 95:
# Loss: [8.6569437e-26]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 96:
# Loss: [4.85485416e-26]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 97:
# Loss: [2.71949952e-26]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 98:
# Loss: [1.52307963e-26]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 99:
# Loss: [8.53850256e-27]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 100:
# Loss: [4.78974925e-27]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 101:
# Loss: [2.69537285e-27]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 102:
# Loss: [1.50882128e-27]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 103:
# Loss: [8.51922015e-28]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 104:
# Loss: [4.76730832e-28]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 105:
# Loss: [2.65964762e-28]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 106:
# Loss: [1.50797233e-28]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 107:
# Loss: [8.47116434e-29]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 108:
# Loss: [4.68016384e-29]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 109:
# Loss: [2.69013895e-29]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 110:
# Loss: [1.42380149e-29]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 111:
# Loss: [8.4509806e-30]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 112:
# Loss: [4.83331379e-30]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 113:
# Loss: [2.71941308e-30]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 114:
# Loss: [1.3882103e-30]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 115:
# Loss: [7.47260818e-31]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 116:
# Loss: [5.00741786e-31]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 117:
# Loss: [3.03526559e-31]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 118:
# Loss: [1.5561514e-31]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 119:
# Loss: [5.70075264e-32]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 120:
# Loss: [5.70075264e-32]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 121:
# Loss: [2.61926472e-32]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 122:
# Loss: [7.70371978e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 123:
# Loss: [7.70371978e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 124:
# Loss: [7.70371978e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 125:
# Loss: [7.70371978e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 126:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 127:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 128:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 129:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 130:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 131:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 132:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 133:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 134:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 135:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 136:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 137:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 138:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 139:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 140:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 141:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 142:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 143:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 144:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 145:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 146:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 147:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 148:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 149:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 150:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 151:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 152:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 153:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 154:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 155:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 156:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 157:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 158:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 159:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 160:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 161:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 162:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 163:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 164:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 165:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 166:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 167:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 168:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 169:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 170:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 171:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 172:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 173:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 174:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 175:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 176:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 177:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 178:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 179:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 180:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 181:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 182:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 183:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 184:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 185:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 186:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 187:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 188:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 189:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 190:
# Loss: [1.54074396e-33]
# ...
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 938:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 939:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 940:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 941:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 942:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 943:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 944:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 945:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 946:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 947:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 948:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 949:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 950:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 951:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 952:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 953:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 954:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 955:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 956:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 957:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 958:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 959:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 960:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 961:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 962:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 963:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 964:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 965:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 966:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 967:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 968:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 969:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 970:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 971:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 972:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 973:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 974:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 975:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 976:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 977:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 978:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 979:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 980:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 981:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 982:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 983:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 984:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 985:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 986:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 987:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 988:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 989:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 990:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 991:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 992:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 993:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 994:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 995:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 996:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 997:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 998:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 999:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# ================================================
# Iteration 1000:
# Loss: [1.54074396e-33]
# Updated Hidden Layer Weights: [[0.53297394 0.71776779]
#  [0.11389455 0.90669712]]
# Updated Output Layer Weights: [[-0.63049573 -0.75362244]
#  [-0.05502178  0.01230643]]
# Loss: [1.54074396e-33]

# %%
import matplotlib.pyplot as plt

print('Loss:', loss[-1])
plt.plot(range(len(loss)), loss)
plt.xlabel('Iterations')
plt.ylabel('Loss')
# Out:
# Loss: [1.54074396e-33]
# Text(0, 0.5, 'Loss')
